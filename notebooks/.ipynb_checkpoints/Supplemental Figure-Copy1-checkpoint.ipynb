# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv ('../data/figure1.csv')

reply = df["r"]
reason = df["Data"]
c=['#FF6A6A','#CD69C9','#9B30FF','#FFC0CB']


plt.pie(reason, colors=c, autopct='%1.1f%%')
plt.legend(loc='upper center', labels = reply, bbox_to_anchor=(0.5, -0), ncol=1, fontsize=15)

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

df = pd.read_csv ('../data/figure2.csv')

x = df.columns[1:].values

data = np.array(df[x])
data = data / data.sum(0) * 100

fig, ax= plt.subplots(figsize=(8,6))

for i in range(len(data)):
    plt.bar(x, data[i], bottom = data[:i].sum(0), width = 0.5)

plt.ylabel('Percentage (%)')
plt.legend(df['people'].values, loc='upper center', bbox_to_anchor=(0.5, -0.06), ncol=4)
#plt.title('Comparisons of ancestry distribution')


#plt.savefig('compare_distribution_0609.png', dpi=300, bbox_inches='tight', pad_inches=2)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv ('../data/figure3.csv')

reason = df["R"]
reply = df["D"]
c=['#B2DFEE','#7D9EC0']

plt.rcParams['font.size'] = 15.0

plt.pie(reply, colors=c, autopct='%1.1f%%', labeldistance=1, startangle=90)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0), ncol=1, labels=reason)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv ('../data/figure4.csv')

reason = df["R"]
reply = df["D"]
colors = ['#FFF68F', '#FFC125']

plt.pie(reply, autopct='%2.1f%%', labels=['']*2, pctdistance=1.25, labeldistance=1.4, startangle=45, colors=colors)
plt.legend(loc='upper center', labels = reason, bbox_to_anchor=(0.5, 0), ncol=2, fontsize=15)

# %%
import matplotlib.pyplot as plt
import numpy as  np

df = pd.read_csv ('../data/figure5.csv')

x = df.columns[1:].values

data = np.array(df[x])
data = data / data.sum(0) * 100
print(data)

width = 0.35

plt.rcParams['font.size'] = 14.0

fig, ax = plt.subplots(figsize=(8,8))

for i in range(4):
    ax.bar(x, data[i], width, label= df['people'].values, bottom = np.sum(data[0:i,:], axis=0))

for row in range(3):
    for people in range(4):
        if row == 0 and people == 3:
            x = row + 0.2
            y = np.sum(data[:people, row]) + (data[people, row] / 2)+1
        else:
            x = row + 0.2
            y = np.sum(data[:people, row]) + (data[people, row] / 2)-1
        ax.text(x, y, "{:.2f}".format(data[people, row]))


ax.set_xlim([-0.4,2.8])
ax.set_ylim([0,110])
ax.set_ylabel('Percentage of participants (%)')
#ax.set_title('Ancestry Distribution over Years')
ax.legend(loc='upper center', labels = df['people'].values, bbox_to_anchor=(0.5, -0.05), ncol=4, fontsize= 15)

plt.savefig('ancestry_distribution_overyears_0609', dpi=300, bbox_inches='tight', pad_inches=2)
# Out:
# [[91.25799574 85.91426072 78.39805825]
#  [ 5.97014925  8.13648294 10.67961165]
#  [ 1.49253731  2.01224847  6.37135922]
#  [ 1.2793177   3.93700787  4.55097087]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

df = pd.read_excel('ancestryboxplot222.xlsx')
df.head()

my_colors = ["#1C86EE", "#FF7F24", "#32CD32"]

sns.set(style='whitegrid')
sns.set_palette( my_colors )

plt.rcParams['font.size'] = 15.0

fig, ax= plt.subplots(figsize=(10,8))


sns.boxplot(x= 'ancestry', y='n', data=df, width=0.5)
sns.stripplot(x= 'ancestry', y='n', data=df, marker='o', alpha=0.5, color='black')
#sns.violinplot(data=df, width=0.5, inner="point")


#plt.title('Number of study participants')
plt.xlabel('REA group', fontsize=15)
plt.ylabel('Number of participants', fontsize=15)
ax.set_yscale('log')

ax.set_ylim([1,1.5E3])



plt.savefig('ancestry boxplot0609.png', dpi=300, bbox_inches='tight', pad_inches=2)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv ('../data/figure7.csv')

reason = df["R"]
reply = df["D"]
#c=['#FF6A6A','#CD69C9','#9B30FF','#FFC0CB']

plt.rcParams['font.size'] = 15.0


plt.pie(reply, autopct='%2.1f%%', labels=['']*4, pctdistance=1.25, labeldistance=1.4)
plt.legend(loc='upper center', labels=reason, bbox_to_anchor=(0.5, -0.0), ncol=2, fontsize=15)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd

df = pd.read_csv ('../data/figure8.csv')

data = np.array(df[df.columns[1:]])
data = data / data.sum(0) * 100

plt.rcParams['font.size'] = 15.0

for i in range(len(data)):
    plt.bar(range(5), data[i], bottom = data[:i].sum(0), width = 1, edgecolor = 'white')
 
#Custom X axis
plt.xticks(range(5), [])
#plt.xticks(rotation=45)
#plt.xlabel("Studies")
plt.xlabel('Study')
plt.ylabel('Percentage (%)')

plt.legend(df['people'].values, loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=2)


#plt.savefig("each_covid_distribution0609.png", dpi=300, bbox_inches='tight', pad_inches=2)
